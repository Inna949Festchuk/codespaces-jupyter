# %% [markdown]
# <a href="https://colab.research.google.com/github/Inna949Festchuk/codespaces-jupyter/blob/main/image_classifier_remotior_sensus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import remotior_sensus
rs = remotior_sensus.Session(n_processes=2, available_ram="6GB")

# %%
print('parallel_processes:', rs.configurations.n_processes)
print('temporary_directory:', rs.configurations.temp.dir)
# Out:
# parallel_processes: 2
# temporary_directory: /tmp/remotior_sensus_1103wkyfmbmr

# %%
catalog = rs.bandset_catalog()

# %%
working_directory = '/home/tutorial'

# %%
query = rs.download_products()
